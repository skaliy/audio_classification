# %% [markdown]
# # Audio classification

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path 
from fastai.vision import *
from fastai.metrics import error_rate
import pandas as pd

# %%
bs = 32

# %%
path = %pwd
path = Path(f'{path}/../data/')

# %%
data = ImageDataBunch.from_folder(path, train="train_melspecs", valid='val_melspecs', ds_tfms=None, size=128, bs=bs)
data.normalize(imagenet_stats)
data.show_batch(rows=3, figsize=(8,8))

# %%
print(data.classes)
# Out:
# ['blink', 'kork', 'skive']

# %% [markdown]
# ## Training

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr= 3e-2
learn.fit_one_cycle(30, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.534888</td>
#       <td>1.546136</td>
#       <td>0.333333</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.983185</td>
#       <td>1.717705</td>
#       <td>0.333333</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.666770</td>
#       <td>1.203485</td>
#       <td>0.571429</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.498328</td>
#       <td>0.778963</td>
#       <td>0.666667</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.396285</td>
#       <td>0.478145</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
#learn.unfreeze()

# %%
#learn.lr_find()
#learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
#learn.fit_one_cycle(4, slice(1e-6,lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000438</td>
#       <td>0.092784</td>
#       <td>0.952381</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.000662</td>
#       <td>0.331135</td>
#       <td>0.857143</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.006064</td>
#       <td>0.276233</td>
#       <td>0.904762</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.006663</td>
#       <td>0.212376</td>
#       <td>0.857143</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
#learn.save('stage-2')

# %%
create_cnndata = ImageDataBunch.from_folder(path, train="train_melspecs", valid='val_melspecs', ds_tfms=None, size=256, bs=bs)
data.normalize(imagenet_stats)
learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-2

# %%
learn.fit_one_cycle(10, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.758763</td>
#       <td>1.084678</td>
#       <td>0.333333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.656083</td>
#       <td>0.844887</td>
#       <td>0.333333</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.579844</td>
#       <td>0.681473</td>
#       <td>0.296296</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.446076</td>
#       <td>0.648333</td>
#       <td>0.296296</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.361608</td>
#       <td>0.567344</td>
#       <td>0.185185</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-3')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1, slice(1e-4,lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.062225</td>
#       <td>0.741472</td>
#       <td>0.222222</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-4')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-1');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix()

# %%
interp.pred_class
# Out:
# tensor([0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 2, 0, 2, 0, 2, 0, 0, 2, 1, 1, 1, 1, 1, 1,
#         1, 1, 1])

# %% [markdown]
# # Production model

# %%
learn.export()
